# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#UnicodeDecodeError: 'utf-8'
df=pd.read_csv("/content/drive/MyDrive/AIDS_April/datasets/laptop_price.csv",encoding='latin')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 12 columns]

# %%
df.sample(3)
# Out:
#      Company                                        Product  \
# 868     Acer  TMX349-G2-M-50FS (i5-7200U/8GB/256GB/FHD/W10)
# 1240  Lenovo                              IdeaPad 320-15ABR
# 1114  Lenovo                                      Yoga Book
#
#                 TypeName  Inches                 ScreenResolution  \
# 868             Notebook    14.0      IPS Panel Full HD 1920x1080
# 1240            Notebook    15.6                Full HD 1920x1080
# 1114  2 in 1 Convertible    10.1  IPS Panel Touchscreen 1920x1200
#
#                               Cpu  Ram              Memory  \
# 868    Intel Core i5 7200U 2.5GHz  8GB           256GB SSD
# 1240  AMD A12-Series 9720P 3.6GHz  6GB           256GB SSD
# 1114  Intel Atom x5-Z8550 1.44GHz  4GB  64GB Flash Storage
#
#                         Gpu       OpSys  Weight  Price_euros
# 868   Intel HD Graphics 620  Windows 10  1.56kg       902.00
# 1240         AMD Radeon 530  Windows 10   2.2kg       597.57
# 1114  Intel HD Graphics 400     Android  0.69kg       549.00

# %%
print(df.isnull().sum())
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(28)

# %%
df.drop_duplicates(inplace=True)

# %%
df.sample()
# Out:
#     Company      Product  TypeName  Inches ScreenResolution  \
# 317  Lenovo  ThinkPad 13  Notebook    13.3         1366x768
#
#                                       Cpu  Ram              Memory  \
# 317  Intel Celeron Dual Core 3855U 1.6GHz  4GB  16GB Flash Storage
#
#                        Gpu      OpSys  Weight  Price_euros
# 317  Intel HD Graphics 510  Chrome OS  1.45kg        459.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1275 entries, 0 to 1274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1275 non-null   object
#  1   Product           1275 non-null   object
#  2   TypeName          1275 non-null   object
#  3   Inches            1275 non-null   float64
#  4   ScreenResolution  1275 non-null   object
#  5   Cpu               1275 non-null   object
#  6   Ram               1275 non-null   object
#  7   Memory            1275 non-null   object
#  8   Gpu               1275 non-null   object
#  9   OpSys             1275 non-null   object
#  10  Weight            1275 non-null   object
#  11  Price_euros       1275 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 129.5+ KB

# %%
# Data processing/Cleaning/EDA
# EDA: Exploratory Data Analysis
# Univariate Analysis
# Divariate Analysis

# %%
df['price']=round(df['Price_euros']*95.72).astype('int')

# %%
df.sample(2)
# Out:
#      Company            Product  TypeName  Inches   ScreenResolution  \
# 918     Dell      Inspiron 7567    Gaming    15.6  Full HD 1920x1080
# 1201  Lenovo  IdeaPad 310-15ISK  Notebook    15.6           1366x768
#
#                               Cpu   Ram                Memory  \
# 918   Intel Core i7 7700HQ 2.8GHz  16GB  128GB SSD +  1TB HDD
# 1201   Intel Core i7 6500U 2.5GHz   8GB             500GB HDD
#
#                              Gpu       OpSys Weight  Price_euros   price
# 918   Nvidia GeForce GTX 1050 Ti  Windows 10  2.6kg       1349.0  129126
# 1201        Nvidia GeForce 920MX       No OS  2.2kg        629.0   60208

# %%
df.drop(columns=['Price_euros'],inplace=True)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                    1366x768
# 1273                                    1366x768
# 1274                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1270            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1271            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1272  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1273            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight   price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg  128235
# 1           Intel HD Graphics 6000       macOS  1.34kg   86047
# 2            Intel HD Graphics 620       No OS  1.86kg   55039
# 3               AMD Radeon Pro 455       macOS  1.83kg  242885
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg  172641
# ...                            ...         ...     ...     ...
# 1270         Intel HD Graphics 520  Windows 10   1.8kg   61069
# 1271         Intel HD Graphics 520  Windows 10   1.3kg  143484
# 1272             Intel HD Graphics  Windows 10   1.5kg   21920
# 1273            AMD Radeon R5 M330  Windows 10  2.19kg   73130
# 1274             Intel HD Graphics  Windows 10   2.2kg   35321
#
# [1275 rows x 12 columns]

# %%
df['Company'].nunique()
# Out:
# 19

# %%
print(df['Company'].value_counts())
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Company'>

# %%
9+7+7+6+4+4+3+3+3+3+2
# Out:
# 51

# %%
51/1275
# Out:
# 0.04

# %%
#removing these 4% of data, from companies which have less than 20 products since its no use of it while making a model

# %%
print(df.groupby('Company')['Company'].transform('count'))
# Out:
# 0        21
# 1        21
# 2       268
# 3        21
# 4        21
#        ...
# 1270    289
# 1271    289
# 1272    289
# 1273    268
# 1274    152
# Name: Company, Length: 1275, dtype: int64

# %%
df=df[df.groupby('Company')['Company'].transform('count')>20]

# %%
print(df['Company'].value_counts())
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       152
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# 1271  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1272                                    1366x768
# 1273                                    1366x768
# 1274                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1270            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1271            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1272  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1273            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1274  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight   price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg  128235
# 1           Intel HD Graphics 6000       macOS  1.34kg   86047
# 2            Intel HD Graphics 620       No OS  1.86kg   55039
# 3               AMD Radeon Pro 455       macOS  1.83kg  242885
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg  172641
# ...                            ...         ...     ...     ...
# 1270         Intel HD Graphics 520  Windows 10   1.8kg   61069
# 1271         Intel HD Graphics 520  Windows 10   1.3kg  143484
# 1272             Intel HD Graphics  Windows 10   1.5kg   21920
# 1273            AMD Radeon R5 M330  Windows 10  2.19kg   73130
# 1274             Intel HD Graphics  Windows 10   2.2kg   35321
#
# [1224 rows x 12 columns]

# %%
#reset the index
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1219  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1220  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1221  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1222      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1223    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1219   IPS Panel Full HD / Touchscreen 1920x1080
# 1220  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1221                                    1366x768
# 1222                                    1366x768
# 1223                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1219            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1220            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1221  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1222            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1223  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight   price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg  128235
# 1           Intel HD Graphics 6000       macOS  1.34kg   86047
# 2            Intel HD Graphics 620       No OS  1.86kg   55039
# 3               AMD Radeon Pro 455       macOS  1.83kg  242885
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg  172641
# ...                            ...         ...     ...     ...
# 1219         Intel HD Graphics 520  Windows 10   1.8kg   61069
# 1220         Intel HD Graphics 520  Windows 10   1.3kg  143484
# 1221             Intel HD Graphics  Windows 10   1.5kg   21920
# 1222            AMD Radeon R5 M330  Windows 10  2.19kg   73130
# 1223             Intel HD Graphics  Windows 10   2.2kg   35321
#
# [1224 rows x 12 columns]

# %%
df['Company'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Company'>

# %%
# Divariate Analysis

# %%
sns.barplot(x=df['Company'],y=df['price'],order=['MSI','Apple','Toshiba','Dell','Asus','Lenovo','HP','Acer'])
# Out:
# <Axes: xlabel='Company', ylabel='price'>

# %%
sorted_company_list=df.groupby('Company')['price'].mean().sort_values(ascending=False)
sorted_company_list
# Out:
# Company
# MSI        165491.055556
# Apple      149725.190476
# Toshiba    121355.000000
# Dell       114789.773196
# Asus       107572.947368
# Lenovo     104704.397924
# HP         103407.656716
# Acer        60635.198020
# Name: price, dtype: float64

# %%
sorted_company_list.index
# Out:
# Index(['MSI', 'Apple', 'Toshiba', 'Dell', 'Asus', 'Lenovo', 'HP', 'Acer'], dtype='object', name='Company')

# %%
sns.barplot(x=df['Company'],y=df['price'],order=sorted_company_list.index,errorbar=None)
# Out:
# <Axes: xlabel='Company', ylabel='price'>

# %%
print(df['Product'].value_counts())
# Out:
# Product
# XPS 13                30
# Inspiron 3567         25
# 250 G6                21
# Vostro 3568           19
# Legion Y520-15IKBN    19
#                       ..
# Portege X30-D-10L      1
# Zenbook UX390UA        1
# Portege X30-D-10J      1
# Latitude E5470         1
# VivoBook E12           1
# Name: count, Length: 589, dtype: int64

# %%
# if the number of categories is more than 20, we will render that column non-meaningful for our analysis.

# %%
df.drop(columns=['Product'],inplace=True)
# Out:
# <ipython-input-36-4bcf6fa0a033>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Product'],inplace=True)

# %%
df.sample()
# Out:
#      Company  TypeName  Inches ScreenResolution                         Cpu  \
# 156  Toshiba  Notebook    15.6         1366x768  Intel Core i3 6006U 2.2GHz
#
#      Ram     Memory                    Gpu       OpSys Weight  price
# 156  4GB  500GB HDD  Intel HD Graphics 520  Windows 10  2.1kg  42787

# %%
#TypeName

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot.bar(color='r')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['price'])
plt.xticks(rotation=45)
plt.show()

# %%
sorted_type_list=df.groupby('TypeName')['price'].mean().sort_values(ascending=False)
sorted_type_list
# Out:
# TypeName
# Workstation           218275.931034
# Gaming                160014.125000
# Ultrabook             148385.766082
# 2 in 1 Convertible    124385.157895
# Notebook               76183.475291
# Netbook                66215.636364
# Name: price, dtype: float64

# %%
sorted_type_list.index
# Out:
# Index(['Workstation', 'Gaming', 'Ultrabook', '2 in 1 Convertible', 'Notebook',
#        'Netbook'],
#       dtype='object', name='TypeName')

# %%
sns.barplot(x=df['TypeName'],y=df['price'],order=sorted_type_list.index,errorbar=None,palette='Greens',hue=df['TypeName'])
plt.xticks(rotation=45)
plt.show()

# %%
palette=sns.color_palette('Greens',len(sorted_type_list))[::-1]
color_dict=dict(zip(sorted_type_list.index,palette))

# %%
sns.barplot(x=df['TypeName'],y=df['price'],order=sorted_type_list.index,errorbar=None,palette=color_dict,hue=df['TypeName'])
plt.xticks(rotation=45)
plt.show()

# %%
print(df['Inches'].value_counts())
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
sns.displot(df['Inches'],kde=True)

# %%
sns.barplot(x=df['Inches'],y=df['price'])
# Out:
# <Axes: xlabel='Inches', ylabel='price'>

# %%
# Screen Resolution

# %%
print(df['ScreenResolution'].value_counts())
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 2560x1440                       3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# 1920x1080                                          2
# IPS Panel Quad HD+ 3200x1800                       2
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Full HD 1366x768                         1
# IPS Panel Full HD 2560x1440                        1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
# df['x_res']
# df['y_res']
# df['Ips']
# df['TouchScreen']

# %%
a="IPS Panel Touchscreen / 4K Ultra HD 3840x2160 "
a.split()
# Out:
# ['IPS', 'Panel', 'Touchscreen', '/', '4K', 'Ultra', 'HD', '3840x2160']

# %%
a.split()[-1]
# Out:
# '3840x2160'

# %%
a.split()[-1].split('x')
# Out:
# ['3840', '2160']

# %%
a.split()[-1].split('x')[0]
# Out:
# '3840'

# %%
(lambda a:a.split()[-1].split('x')[0])
# Out:
# <function __main__.<lambda>(a)>

# %%
df['x_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
df['y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[1]).astype('int')
# Out:
# <ipython-input-58-01dc1926ce29>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['x_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
# <ipython-input-58-01dc1926ce29>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[1]).astype('int')

# %%
df['x_res']
# Out:
# 0       2560
# 1       1440
# 2       1920
# 3       2880
# 4       2560
#         ...
# 1219    1920
# 1220    3200
# 1221    1366
# 1222    1366
# 1223    1366
# Name: x_res, Length: 1224, dtype: int64

# %%
df['y_res']
# Out:
# 0       1600
# 1        900
# 2       1080
# 3       1800
# 4       1600
#         ...
# 1219    1080
# 1220    1800
# 1221     768
# 1222     768
# 1223     768
# Name: y_res, Length: 1224, dtype: int64

# %%
a
# Out:
# 'IPS Panel Touchscreen / 4K Ultra HD 3840x2160 '

# %%
lambda a:[1 if 'IPS' in a else 0]
# Out:
# <function __main__.<lambda>(a)>

# %%
df['IPS']=df['ScreenResolution'].apply(lambda a:1 if 'IPS' in a else 0)
df['IPS']
# Out:
# <ipython-input-63-1cfcc56d7a6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IPS']=df['ScreenResolution'].apply(lambda a:1 if 'IPS' in a else 0)
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 1219    1
# 1220    1
# 1221    0
# 1222    0
# 1223    0
# Name: IPS, Length: 1224, dtype: int64

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if 'Touchscreen' in a else 0)
df['Touchscreen']
# Out:
# <ipython-input-64-57e627fe2cb8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if 'Touchscreen' in a else 0)
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1219    1
# 1220    1
# 1221    0
# 1222    0
# 1223    0
# Name: Touchscreen, Length: 1224, dtype: int64

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 109   Lenovo  2 in 1 Convertible    13.3
# 1110      HP  2 in 1 Convertible    13.3
# 360       HP           Ultrabook    14.0
# 682     Dell            Notebook    15.6
# 1140    Acer              Gaming    17.3
#
#                                ScreenResolution                          Cpu  \
# 109   IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i5 7200U 2.5GHz
# 1110                      Touchscreen 2560x1440   Intel Core i7 6600U 2.6GHz
# 360                 IPS Panel Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# 682                           Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1140                IPS Panel Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
#
#        Ram                Memory                      Gpu       OpSys  Weight  \
# 109    8GB             256GB SSD    Intel HD Graphics 620  Windows 10  1.37kg
# 1110   8GB             512GB SSD    Intel HD Graphics 520  Windows 10  1.48kg
# 360    8GB             256GB SSD    Intel HD Graphics 620  Windows 10  1.36kg
# 682    8GB               1TB HDD    Intel HD Graphics 620       Linux  1.98kg
# 1140  16GB  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10   4.2kg
#
#        price  x_res  y_res  IPS  Touchscreen
# 109   133912   1920   1080    1            1
# 1110  195365   2560   1440    0            1
# 360   167510   1920   1080    1            0
# 682    69493   1920   1080    0            0
# 1140  248776   1920   1080    1            0

# %%
df.drop(columns=['ScreenResolution'],inplace=True)
# Out:
# <ipython-input-66-5a8c076be408>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.sample(4)
# Out:
#      Company            TypeName  Inches                          Cpu   Ram  \
# 1093      HP  2 in 1 Convertible    13.3   Intel Core i5 6300U 2.4GHz   8GB
# 317     Acer            Notebook    15.6   Intel Core i5 7200U 2.5GHz   6GB
# 437     Dell         Workstation    15.6  Intel Core i7 6820HQ 2.7GHz  16GB
# 710     Dell            Notebook    15.6     Intel Core i3 6006U 2GHz   8GB
#
#          Memory                    Gpu       OpSys  Weight   price  x_res  \
# 1093  256GB SSD  Intel HD Graphics 520  Windows 10  1.48kg  155928   1920
# 317     1TB HDD  Intel HD Graphics 620  Windows 10  2.23kg   52550   1366
# 437   256GB SSD     Nvidia Quadro M620  Windows 10  2.17kg  189047   1920
# 710   256GB SSD  Intel HD Graphics 520  Windows 10     2kg   63654   1366
#
#       y_res  IPS  Touchscreen
# 1093   1080    0            1
# 317     768    0            0
# 437    1080    1            0
# 710     768    0            0

# %%
print(df['Cpu'].value_counts())
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz              183
# Intel Core i7 7700HQ 2.8GHz             142
# Intel Core i7 7500U 2.7GHz              124
# Intel Core i5 8250U 1.6GHz               71
# Intel Core i7 8550U 1.8GHz               71
#                                        ...
# Intel Pentium Dual Core 4405Y 1.5GHz      1
# Intel Core M 6Y54 1.1GHz                  1
# AMD E-Series 9000 2.2GHz                  1
# Intel Core M 6Y30 0.9GHz                  1
# AMD A9-Series 9410 2.9GHz                 1
# Name: count, Length: 111, dtype: int64

# %%
df['Cpu'].apply(lambda x:x.split()[-1].replace("GHz","")).astype('float')
# Out:
# 0       2.3
# 1       1.8
# 2       2.5
# 3       2.7
# 4       3.1
#        ...
# 1219    2.5
# 1220    2.5
# 1221    1.6
# 1222    2.5
# 1223    1.6
# Name: Cpu, Length: 1224, dtype: float64

# %%
df['Cpu_speed']=df['Cpu'].apply(lambda x:x.split()[-1].replace("GHz","")).astype('float')
df['Cpu_speed']
# Out:
# <ipython-input-70-84bfb880f980>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu_speed']=df['Cpu'].apply(lambda x:x.split()[-1].replace("GHz","")).astype('float')
# 0       2.3
# 1       1.8
# 2       2.5
# 3       2.7
# 4       3.1
#        ...
# 1219    2.5
# 1220    2.5
# 1221    1.6
# 1222    2.5
# 1223    1.6
# Name: Cpu_speed, Length: 1224, dtype: float64

# %%
a="Intel Core i5 7200U"  # splitting
a.split()[0:3]
# Out:
# ['Intel', 'Core', 'i5']

# %%
# Rejoining
" ".join(a.split())
# Out:
# 'Intel Core i5 7200U'

# %%
print(df['Cpu'].apply(lambda x:x.split()[0:3]))
# Out:
# 0            [Intel, Core, i5]
# 1            [Intel, Core, i5]
# 2            [Intel, Core, i5]
# 3            [Intel, Core, i7]
# 4            [Intel, Core, i5]
#                  ...
# 1219         [Intel, Core, i7]
# 1220         [Intel, Core, i7]
# 1221    [Intel, Celeron, Dual]
# 1222         [Intel, Core, i7]
# 1223    [Intel, Celeron, Dual]
# Name: Cpu, Length: 1224, dtype: object

# %%
df['Cpu']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
# Out:
# <ipython-input-74-aa3ac16de377>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df['Cpu']
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1219         Intel Core i7
# 1220         Intel Core i7
# 1221    Intel Celeron Dual
# 1222         Intel Core i7
# 1223    Intel Celeron Dual
# Name: Cpu, Length: 1224, dtype: object

# %%
def fetch_processor_name(text):
  if "Core" in text:
    return text
  elif text.split()[0]=='Intel':
    return " ".join(text.split()[0:2])
  elif text.split()[0]=='AMD':
    if text[4]=="A":
      return "AMD A-Series"
    elif text[4]=="E":
      return "AMD E-Series"
    elif text[4]=="R":
      return "AMD Ryzen Series"
    elif text[4]=="F":
      return "AMD FX Series"
    else:
      return "other processor"

# %%
df['Cpu']=df['Cpu'].apply(fetch_processor_name)
# Out:
# <ipython-input-77-8c092dd80c87>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].apply(fetch_processor_name)

# %%
df['Cpu'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x=df['Cpu'],y=df['price'])
plt.xticks(rotation=45)
plt.show()

# %%
sorted_cpu_list=df.groupby('Cpu')['price'].mean().sort_values(ascending=False)
print(sorted_cpu_list)
# Out:
# Cpu
# Intel Xeon          343060.500000
# AMD Ryzen Series    161335.750000
# Intel Core i7       151240.478702
# Intel Core M        135882.875000
# Intel Core i5        96865.690998
# AMD FX Series        81266.000000
# Intel Core i3        51962.417910
# AMD A-Series         47884.733333
# Intel Atom           41833.000000
# Intel Pentium        41689.866667
# Intel Celeron        30890.591549
# AMD E-Series         28800.888889
# Name: price, dtype: float64

# %%
sorted_cpu_list.index
# Out:
# Index(['Intel Xeon', 'AMD Ryzen Series', 'Intel Core i7', 'Intel Core M',
#        'Intel Core i5', 'AMD FX Series', 'Intel Core i3', 'AMD A-Series',
#        'Intel Atom', 'Intel Pentium', 'Intel Celeron', 'AMD E-Series'],
#       dtype='object', name='Cpu')

# %%
palette=sns.color_palette('Greens',len(sorted_cpu_list))[::-1]
color_dict=dict(zip(sorted_cpu_list.index,palette))

# %%
sns.barplot(x=df['Cpu'],y=df['price'],order=sorted_cpu_list.index,errorbar=None,palette=color_dict,hue=df['Cpu'])
plt.xticks(rotation=45)
plt.show()

# %%
print(df['Ram'].value_counts())
# Out:
# Ram
# 8GB     595
# 4GB     351
# 16GB    186
# 6GB      34
# 12GB     25
# 32GB     15
# 2GB      14
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
df['Ram']=df['Ram'].apply(lambda y:y.replace("GB","")).astype('int')
# Out:
# <ipython-input-85-2c4b40add816>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram']=df['Ram'].apply(lambda y:y.replace("GB","")).astype('int')

# %%
df['Weight']=df['Weight'].apply(lambda y:y.replace("kg","")).astype('float')
# Out:
# <ipython-input-86-b682b9ab08be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight']=df['Weight'].apply(lambda y:y.replace("kg","")).astype('float')

# %%
df['Ram']
# Out:
# 0        8
# 1        8
# 2        8
# 3       16
# 4        8
#         ..
# 1219     4
# 1220    16
# 1221     2
# 1222     6
# 1223     4
# Name: Ram, Length: 1224, dtype: int64

# %%
df['Weight']
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1219    1.80
# 1220    1.30
# 1221    1.50
# 1222    2.19
# 1223    2.20
# Name: Weight, Length: 1224, dtype: float64

# %%
df.sample()
# Out:
#     Company            TypeName  Inches            Cpu  Ram  \
# 339    Asus  2 in 1 Convertible    11.6  Intel Celeron    4
#
#                  Memory                    Gpu       OpSys  Weight  price  \
# 339  32GB Flash Storage  Intel HD Graphics 500  Windows 10     1.5  35895
#
#      x_res  y_res  IPS  Touchscreen  Cpu_speed
# 339   1366    768    0            1        1.1

# %%
ram_list=df.groupby('Ram')['price'].mean()
ram_list.index
color_p=sns.color_palette('Reds',len(ram_list))
color_p
# Out:
# [(0.9969242599000384, 0.8961937716262975, 0.8489042675893886),
#  (0.9913725490196079, 0.7913725490196079, 0.7082352941176471),
#  (0.9882352941176471, 0.6715417147251057, 0.5605382545174933),
#  (0.9874509803921568, 0.5411764705882353, 0.41568627450980394),
#  (0.9835755478662053, 0.4127950788158401, 0.28835063437139563),
#  (0.9466666666666667, 0.26823529411764707, 0.19607843137254902),
#  (0.8503344867358708, 0.14686658977316416, 0.13633217993079583),
#  (0.7364705882352941, 0.08, 0.10117647058823528),
#  (0.5946174548250673, 0.04613610149942329, 0.07558631295655516)]

# %%
sns.barplot(x=df['Ram'],y=df['price'],errorbar=None,palette=color_p,hue=df['Ram'])
plt.xticks()
plt.show()

# %%
df['IPS'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['price'])
# Out:
# <Axes: xlabel='IPS', ylabel='price'>

# %%
df['Touchscreen'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='price'>

# %%
print(df['Cpu_speed'].value_counts())
# Out:
# Cpu_speed
# 2.50    274
# 2.80    160
# 2.70    156
# 1.60    122
# 2.00     85
# 2.30     84
# 1.80     76
# 2.60     74
# 2.40     50
# 1.10     47
# 3.00     19
# 2.90     17
# 1.20     13
# 2.20     10
# 1.50     10
# 1.30      5
# 3.60      5
# 1.44      5
# 3.10      3
# 2.10      3
# 1.90      2
# 0.90      2
# 1.00      1
# 3.20      1
# Name: count, dtype: int64

# %%
sns.displot(df['Cpu_speed'],kde=True)

# %%
sns.scatterplot(x=df['Cpu_speed'],y=df['price'],hue=df['TypeName'])
plt.legend()
plt.show()

# %%
sns.scatterplot(x=df['Cpu_speed'],y=df['price'],hue=df['Cpu'])
plt.legend(loc='upper right',bbox_to_anchor=(1.5,1))
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1224 non-null   object
#  1   TypeName     1224 non-null   object
#  2   Inches       1224 non-null   float64
#  3   Cpu          1224 non-null   object
#  4   Ram          1224 non-null   int64
#  5   Memory       1224 non-null   object
#  6   Gpu          1224 non-null   object
#  7   OpSys        1224 non-null   object
#  8   Weight       1224 non-null   float64
#  9   price        1224 non-null   int64
#  10  x_res        1224 non-null   int64
#  11  y_res        1224 non-null   int64
#  12  IPS          1224 non-null   int64
#  13  Touchscreen  1224 non-null   int64
#  14  Cpu_speed    1224 non-null   float64
# dtypes: float64(3), int64(6), object(6)
# memory usage: 143.6+ KB

# %%
sns.displot(df['Weight'],kde=True)

# %%
sns.scatterplot(x=df['Weight'],y=df['price'],hue=df['TypeName'])
# Out:
# <Axes: xlabel='Weight', ylabel='price'>

# %%
df_g=df[df['TypeName']=='Gaming']

# %%
sns.scatterplot(x=df_g['Weight'],y=df_g['price'])
# Out:
# <Axes: xlabel='Weight', ylabel='price'>

# %%
sns.scatterplot(x=df['Weight'],y=df['price'],hue=df['Inches'])
# Out:
# <Axes: xlabel='Weight', ylabel='price'>

# %%
import plotly.express as px
px.scatter(x=df['Weight'],y=df['price'],color=df['TypeName'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fc2c59b7-52b9-4588-ae2c-b7baddb2523a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc2c59b7-52b9-4588-ae2c-b7baddb2523a")) {                    Plotly.newPlot(                        "fc2c59b7-52b9-4588-ae2c-b7baddb2523a",                        [{"hovertemplate":"color=Ultrabook\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ultrabook","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Ultrabook","showlegend":true,"x":[1.37,1.34,1.83,1.37,2.04,1.34,1.3,1.6,1.83,0.92,1.37,1.83,1.22,1.91,1.35,1.88,1.2,1.35,1.37,1.7,1.8,1.4,1.88,0.92,1.83,1.21,1.25,1.38,1.3,1.5,1.23,1.21,1.6,1.25,0.97,1.48,1.23,1.12,1.21,1.2,1.4,1.6,1.2,1.37,1.41,1.37,1.7,1.63,1.21,1.7,1.26,1.9,1.2,1.88,1.9,1.36,1.1,1.13,1.91,1.13,1.1,1.2,1.36,1.7,1.43,1.75,1.6,1.32,1.36,1.4,1.42,1.36,0.91,1.05,1.3,1.34,1.29,1.32,1.2,1.34,1.16,1.21,1.24,1.4,1.84,1.1,1.23,1.14,1.8,1.36,1.2,1.1,1.36,1.17,1.32,1.7,1.18,1.2,1.26,1.47,1.7,0.92,1.29,1.32,1.25,1.13,1.13,1.1,1.54,1.45,1.54,1.96,1.29,1.2,1.6,1.32,1.13,1.09,1.84,1.39,1.36,1.26,1.36,1.36,1.36,1.7,1.3,1.36,1.1,1.5,1.11,1.48,1.43,1.26,1.54,1.2,1.26,1.29,1.26,1.47,1.2,1.29,0.92,1.26,1.3,0.99,1.3,1.4,1.5,1.5,1.5,1.16,1.23,1.05,1.26,1.84,1.88,1.26,1.4,1.7,1.54,1.23,0.92,1.2,0.92,1.26,1.29,1.08,1.54,1.45,1.2],"xaxis":"x","y":[128235,86047,242885,172641,204838,110911,143101,73704,233554,120837,145356,273568,93710,63079,105196,124245,178901,95529,135827,84138,189813,91413,104924,144537,66908,157842,100410,107111,114194,120799,131998,155928,84616,105196,192780,103569,133912,94667,186558,138698,89200,109982,130466,195269,90838,187506,93518,140517,239204,100496,127786,100410,151142,153914,63462,167510,167405,218433,47764,251265,179284,167223,160810,185984,143580,116336,105196,228005,136784,177848,176302,172105,186654,267920,105196,126638,86052,133912,133912,109599,188090,153056,178518,160140,132955,181868,178901,234514,87967,151620,138784,108642,179666,161445,143484,104909,177943,108068,119076,168850,220060,111514,143484,177943,104335,239204,179475,200916,178996,98209,140517,182155,214413,104813,161767,172200,196130,296732,124148,109982,157938,151142,156885,140919,169903,142526,121373,168467,171339,187896,129126,199959,138698,147313,180644,152195,149227,155449,129126,165117,215753,139560,124436,114768,164015,133912,196130,78332,108657,111702,135262,188473,131998,213073,181389,71981,207877,219864,220060,143484,79543,105196,111322,256530,122426,164004,141378,91795,210411,122522,69780],"yaxis":"y","type":"scattergl"},{"hovertemplate":"color=Notebook\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Notebook","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Notebook","showlegend":true,"x":[1.86,2.1,1.86,1.86,2.2,2.2,2.2,1.86,2.3,2.2,2.5,1.65,2.71,1.44,2.1,2.8,1.86,2.1,2.0,2.3,2.2,2.2,2.3,2.8,2.2,1.86,1.49,2.4,2.13,1.91,2.0,2.0,2.8,1.7,1.4,1.86,1.86,1.44,1.9,2.2,2.1,2.2,2.02,2.2,2.5,1.63,2.2,2.1,1.96,2.2,1.49,2.2,2.2,2.0,1.91,2.1,2.2,1.58,1.85,1.58,1.63,1.63,2.16,2.0,1.7,2.1,2.2,2.5,2.1,1.86,1.63,1.65,2.8,2.5,2.36,2.2,2.2,2.05,1.63,1.9,2.2,1.32,3.0,1.75,2.1,1.86,2.0,2.1,1.9,1.91,2.1,2.03,3.0,2.13,2.1,2.1,3.0,1.49,2.71,2.2,2.0,2.5,2.3,2.1,1.9,2.02,2.0,2.77,2.06,2.8,2.8,2.5,1.49,2.5,2.1,2.23,2.3,2.2,2.4,2.1,2.2,2.8,1.63,2.2,2.1,2.2,2.3,2.0,2.69,1.9,2.37,2.1,1.6,2.36,2.1,2.2,2.2,2.1,2.69,2.2,2.04,1.49,1.68,3.0,1.91,2.9,2.8,2.2,2.1,2.18,2.24,2.2,2.5,2.05,2.14,2.2,2.3,2.8,2.2,2.8,2.8,2.8,2.25,2.2,3.0,2.15,1.95,2.2,2.19,2.54,2.0,2.05,2.5,2.4,1.3,2.8,2.2,2.2,2.2,2.3,1.86,1.1,2.23,2.33,1.45,1.95,1.4,1.48,2.79,2.0,2.1,2.2,1.44,2.23,2.06,2.0,2.0,1.85,1.48,1.84,2.0,2.0,2.2,2.2,2.1,1.44,2.06,1.84,2.4,2. ...

# %%
print(df['Gpu'].value_counts())
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# AMD Radeon R5 M315           1
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:" ".join(x.split()[0:2]))
# Out:
# <ipython-input-108-2666f22119d7>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD          586
# Nvidia GeForce    353
# AMD Radeon        166
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# AMD FirePro         5
# Nvidia GTX          1
# AMD R4              1
# AMD R17M-M1-70      1
# Intel Graphics      1
# Name: count, dtype: int64

# %%
def gpu_names(text):
  if text=="Intel Graphics":
    return "Intel HD"
  elif text=="AMD R17M-M1-70" or text=="AMD R4":
    return "AMD Radeon"
  elif text=="Nvidia GTX":
    return "Nvidia GeForce"
  else:
    return text

# %%
df['Gpu']=df['Gpu'].apply(gpu_names)
# Out:
# <ipython-input-111-1526e45c92c6>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df['Gpu'].value_counts())
# Out:
# Gpu
# Intel HD          587
# Nvidia GeForce    354
# AMD Radeon        168
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# AMD FirePro         5
# Name: count, dtype: int64

# %%
sorted_gpu_list=df.groupby('Gpu')['price'].mean().sort_values(ascending=False)
print(sorted_gpu_list)
# Out:
# Gpu
# Nvidia Quadro     235328.483871
# Intel Iris        165480.090909
# AMD FirePro       156712.800000
# Nvidia GeForce    131904.392655
# Intel UHD         115416.044118
# Intel HD           94231.223169
# AMD Radeon         71443.297619
# Name: price, dtype: float64

# %%
sorted_gpu_list.index
# Out:
# Index(['Nvidia Quadro', 'Intel Iris', 'AMD FirePro', 'Nvidia GeForce',
#        'Intel UHD', 'Intel HD', 'AMD Radeon'],
#       dtype='object', name='Gpu')

# %%
palette=sns.color_palette('Greens',len(sorted_gpu_list))[::-1]
color_dict=dict(zip(sorted_gpu_list.index,palette))

# %%
sns.barplot(x=df['Gpu'],y=df['price'],errorbar=None,order=sorted_gpu_list.index,palette=color_dict,hue=df['Gpu'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#     Company     TypeName  Inches            Cpu  Ram     Memory  \
# 379    Dell  Workstation    15.6  Intel Core i7    8  256GB SSD
#
#                Gpu       OpSys  Weight   price  x_res  y_res  IPS  \
# 379  Nvidia Quadro  Windows 10     2.0  204362   1920   1080    1
#
#      Touchscreen  Cpu_speed
# 379            0        2.7

# %%
print(df['OpSys'].value_counts())
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Windows 10 S       2
# Android            2
# Name: count, dtype: int64

# %%
def fetch_os_name(text):
    if text=="Windows 10 S":
        return "Windows 10"
    elif text=="Mac OS X" or text=="macOS":
        return "Mac OS"
    elif text=="Chrome OS" or text=="Linux" or text=="Android":
        return "Linux/Others"
    else:
        return text

# %%
df['OpSys']=df['OpSys'].apply(fetch_os_name)
# Out:
# <ipython-input-120-21b8552f1324>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df['OpSys'].value_counts())
# Out:
# OpSys
# Windows 10      1013
# Linux/Others      82
# No OS             63
# Windows 7         45
# Mac OS            21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='OpSys'>

# %%
sorted_os_list=df.groupby('OpSys')['price'].mean().sort_values(ascending=False)
print(sorted_os_list)
palette=sns.color_palette('Reds',len(sorted_os_list))[::-1]
color_dict=dict(zip(sorted_os_list.index,palette))
# Out:
# OpSys
# Windows 7       161446.177778
# Mac OS          149725.190476
# Windows 10      112125.036525
# Linux/Others     53605.597561
# No OS            53492.825397
# Name: price, dtype: float64

# %%
sns.barplot(x=df['OpSys'],y=df['price'],errorbar=None,order=sorted_os_list.index,
            palette=color_dict,hue=df['OpSys'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#    Company   TypeName  Inches            Cpu  Ram     Memory         Gpu  \
# 69    Dell  Ultrabook    13.3  Intel Core i7    8  256GB SSD  AMD Radeon
#
#          OpSys  Weight  price  x_res  y_res  IPS  Touchscreen  Cpu_speed
# 69  Windows 10     1.4  91413   1920   1080    1            0        1.8

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 256GB SSD +  2TB HDD              10
# 64GB Flash Storage                10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 32GB SSD                           2
# 256GB SSD +  256GB SSD             2
# 1TB SSD +  1TB HDD                 2
# 512GB Flash Storage                2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 512GB SSD +  512GB SSD             1
# 64GB SSD                           1
# 64GB Flash Storage +  1TB HDD      1
# 512GB SSD +  256GB SSD             1
# 1TB HDD +  1TB HDD                 1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# HDD
# SSD
# Flash Storage
# Hybrid

# %%
df['Memory']=df['Memory'].astype('str').replace("\.0","",regex=True)
# Out:
# <ipython-input-128-26fa70b28114>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Memory']=df['Memory'].str.replace("GB","")
df['Memory']=df['Memory'].str.replace("TB","000")
# Out:
# <ipython-input-129-8ed97e19a654>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-129-8ed97e19a654>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256 SSD                         393
# 1000 HDD                        215
# 500 HDD                         124
# 512 SSD                         105
# 128 SSD +  1000 HDD              93
# 256 SSD +  1000 HDD              73
# 128 SSD                          71
# 32 Flash Storage                 29
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         12
# 64 Flash Storage                 10
# 256 SSD +  2000 HDD              10
# 256 Flash Storage                 8
# 1000 Hybrid                       7
# 16 Flash Storage                  6
# 180 SSD                           5
# 128 Flash Storage                 4
# 512 SSD +  2000 HDD               3
# 16 SSD                            3
# 256 SSD +  256 SSD                2
# 512 Flash Storage                 2
# 128 SSD +  2000 HDD               2
# 32 SSD                            2
# 256 SSD +  500 HDD                2
# 1000 SSD +  1000 HDD              2
# 64 SSD                            1
# 512 SSD +  256 SSD                1
# 512 SSD +  512 SSD                1
# 1000 HDD +  1000 HDD              1
# 64 Flash Storage +  1000 HDD      1
# 128 HDD                           1
# 240 SSD                           1
# 8 SSD                             1
# 508 Hybrid                        1
# 512 SSD +  1000 Hybrid            1
# 256 SSD +  1000 Hybrid            1
# Name: count, dtype: int64

# %%
new=df['Memory'].str.split('+',expand=True)
df['first']=new[0]
df['first']=df['first'].str.strip()
df['second']=new[1]
# Out:
# <ipython-input-131-880982f97623>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-131-880982f97623>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-131-880982f97623>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer1Flash']=df['first'].apply(lambda x:1 if "Flash" in x else 0)
# Out:
# <ipython-input-132-4978ec531ce1>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-132-4978ec531ce1>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-132-4978ec531ce1>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-132-4978ec531ce1>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['first']=df['first'].str.replace(r'\D','',regex=True)
# Out:
# <ipython-input-133-043ccd27c636>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['second'].fillna("0",inplace=True)
df['second']=df['second'].str.strip()
# Out:
# <ipython-input-134-35a0e6b0e560>:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# <ipython-input-134-35a0e6b0e560>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-134-35a0e6b0e560>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Layer2HDD']=df['second'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer2Flash']=df['second'].apply(lambda x:1 if "Flash" in x else 0)
# Out:
# <ipython-input-135-4e7f321ddd0d>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-135-4e7f321ddd0d>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-135-4e7f321ddd0d>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-135-4e7f321ddd0d>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['second']=df['second'].str.replace(r'\D','',regex=True)
# Out:
# <ipython-input-136-7e4a144e1deb>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['first']=df['first'].astype('int')
df['second']=df['second'].astype('int')
# Out:
# <ipython-input-137-985d4fe1ffcd>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-137-985d4fe1ffcd>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
df['Flash_Storage']=df['first']*df['Layer1Flash']+df['second']*df['Layer2Flash']
# Out:
# <ipython-input-138-ab0518cd5d0c>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-138-ab0518cd5d0c>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-138-ab0518cd5d0c>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-138-ab0518cd5d0c>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash',
                 'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash'],inplace=True)
# Out:
# <ipython-input-139-181153d3af2d>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.drop(columns=['Memory'],inplace=True)
# Out:
# <ipython-input-140-8cab1fd6fcc0>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sample(4)
# Out:
#      Company   TypeName  Inches            Cpu  Ram             Gpu  \
# 1140    Acer     Gaming    17.3  Intel Core i7   16  Nvidia GeForce
# 29        HP   Notebook    17.3  Intel Core i5    8  Nvidia GeForce
# 980       HP   Notebook    14.0  Intel Core i5    4        Intel HD
# 850   Lenovo  Ultrabook    14.0  Intel Core i5    8        Intel HD
#
#            OpSys  Weight   price  x_res  y_res  IPS  Touchscreen  Cpu_speed  \
# 1140  Windows 10    4.20  248776   1920   1080    1            0        2.8
# 29    Windows 10    2.50   85765   1920   1080    0            0        1.6
# 980   Windows 10    2.31  113811   1366    768    0            0        2.5
# 850   Windows 10    1.32  172200   1920   1080    1            0        2.5
#
#        HDD  SSD  Hybrid  Flash_Storage
# 1140  1000  256       0              0
# 29    1000    0       0              0
# 980    500    0       0              0
# 850      0  256       0              0

# %%
df.corr(numeric_only=True)
# Out:
#                  Inches       Ram    Weight     price     x_res     y_res  \
# Inches         1.000000  0.239155  0.824959  0.055330 -0.057739 -0.071772
# Ram            0.239155  1.000000  0.394187  0.726639  0.415731  0.412278
# Weight         0.824959  0.394187  1.000000  0.212038 -0.025155 -0.036765
# price          0.055330  0.726639  0.212038  1.000000  0.553707  0.552964
# x_res         -0.057739  0.415731 -0.025155  0.553707  1.000000  0.997454
# y_res         -0.071772  0.412278 -0.036765  0.552964  0.997454  1.000000
# IPS           -0.104090  0.223322  0.038753  0.289225  0.283969  0.294360
# Touchscreen   -0.359497  0.094037 -0.291506  0.161443  0.320954  0.317174
# Cpu_speed      0.296510  0.356482  0.313267  0.422535  0.187056  0.178539
# HDD            0.525077  0.106175  0.503765 -0.093770 -0.109044 -0.115936
# SSD           -0.114322  0.589636 -0.063144  0.654751  0.523882  0.518090
# Hybrid         0.050989  0.052774  0.105129  0.025523 -0.000097 -0.000967
# Flash_Storage -0.230659 -0.047725 -0.178962 -0.023384 -0.013602  0.020131
#
#                     IPS  Touchscreen  Cpu_speed       HDD       SSD    Hybrid  \
# Inches        -0.104090    -0.359497   0.296510  0.525077 -0.114322  0.050989
# Ram            0.223322     0.094037   0.356482  0.106175  0.589636  0.052774
# Weight         0.038753    -0.291506   0.313267  0.503765 -0.063144  0.105129
# price          0.289225     0.161443   0.422535 -0.093770  0.654751  0.025523
# x_res          0.283969     0.320954   0.187056 -0.109044  0.523882 -0.000097
# y_res          0.294360     0.317174   0.178539 -0.115936  0.518090 -0.000967
# IPS            1.000000     0.154500   0.085098 -0.087397  0.228186 -0.013349
# Touchscreen    0.154500     1.000000  -0.105203 -0.195492  0.240469 -0.035892
# Cpu_speed      0.085098    -0.105203   1.000000  0.115310  0.248993  0.049271
# HDD           -0.087397    -0.195492   0.115310  1.000000 -0.407685 -0.073848
# SSD            0.228186     0.240469   0.248993 -0.407685  1.000000 -0.050250
# Hybrid        -0.013349    -0.035892   0.049271 -0.073848 -0.050250  1.000000
# Flash_Storage  0.074771    -0.012073  -0.214263 -0.112475 -0.140474 -0.012602
#
#                Flash_Storage
# Inches             -0.230659
# Ram                -0.047725
# Weight             -0.178962
# price              -0.023384
# x_res              -0.013602
# y_res               0.020131
# IPS                 0.074771
# Touchscreen        -0.012073
# Cpu_speed          -0.214263
# HDD                -0.112475
# SSD                -0.140474
# Hybrid             -0.012602
# Flash_Storage       1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),cmap='summer')
# Out:
# <Axes: >

# %%
print(df.corr(numeric_only=True)['price'])
# Out:
# Inches           0.055330
# Ram              0.726639
# Weight           0.212038
# price            1.000000
# x_res            0.553707
# y_res            0.552964
# IPS              0.289225
# Touchscreen      0.161443
# Cpu_speed        0.422535
# HDD             -0.093770
# SSD              0.654751
# Hybrid           0.025523
# Flash_Storage   -0.023384
# Name: price, dtype: float64

# %%
# ppi: pixel density

# %%
df['ppi']=round((df['x_res']**2+df['y_res']**2)**0.5/df['Inches']).astype('int')
# Out:
# <ipython-input-146-996f9ee49e56>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df.corr(numeric_only=True)['price'])
# Out:
# Inches           0.055330
# Ram              0.726639
# Weight           0.212038
# price            1.000000
# x_res            0.553707
# y_res            0.552964
# IPS              0.289225
# Touchscreen      0.161443
# Cpu_speed        0.422535
# HDD             -0.093770
# SSD              0.654751
# Hybrid           0.025523
# Flash_Storage   -0.023384
# ppi              0.483821
# Name: price, dtype: float64

# %%
df.drop(columns=['Inches','x_res','y_res'],inplace=True)
# Out:
# <ipython-input-148-76429cb9627c>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)
# Out:
# <ipython-input-149-06b8a3d14dd7>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df.corr(numeric_only=True)['price'])
# Out:
# Ram            0.726639
# Weight         0.212038
# price          1.000000
# IPS            0.289225
# Touchscreen    0.161443
# Cpu_speed      0.422535
# HDD           -0.093770
# SSD            0.654751
# ppi            0.483821
# Name: price, dtype: float64

# %%
df.sample(3)
# Out:
#      Company            TypeName            Cpu  Ram             Gpu  \
# 497       HP            Notebook  Intel Core i5    4       Intel UHD
# 1192    Dell  2 in 1 Convertible  Intel Core i7   16  Nvidia GeForce
# 187     Dell  2 in 1 Convertible  Intel Core i7    8       Intel UHD
#
#            OpSys  Weight   price  IPS  Touchscreen  Cpu_speed   HDD  SSD  ppi
# 497   Windows 10    2.04   49915    0            1        1.6  1000    0  100
# 1192  Windows 10    2.77  172200    0            1        2.7     0  512  127
# 187   Windows 10    1.62   80309    1            1        1.8  1000    0  166

# %%
df['SSD'].value_counts()
# Out:
# SSD
# 256     479
# 0       425
# 128     166
# 512     125
# 1000     14
# 180       5
# 16        3
# 32        2
# 64        1
# 1024      1
# 768       1
# 240       1
# 8         1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['SSD'],y=df['price'])
# Out:
# <Axes: xlabel='SSD', ylabel='price'>

# %%
sns.displot(df['ppi'],kde=True)

# %%
sns.scatterplot(x=df['ppi'],y=df['price'])
# Out:
# <Axes: xlabel='ppi', ylabel='price'>

# %%
df.sample()
# Out:
#    Company  TypeName            Cpu  Ram        Gpu       OpSys  Weight  \
# 90      HP  Notebook  Intel Core i7   16  Intel UHD  Windows 10    1.49
#
#      price  IPS  Touchscreen  Cpu_speed  HDD  SSD  ppi
# 90  114577    0            0        1.8    0  512  166

# %%
sns.kdeplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
print(df['price'].describe())
# Out:
# count      1224.000000
# mean     107645.160131
# std       64118.113675
# min       16655.000000
# 25%       58666.750000
# 50%       93710.000000
# 75%      141426.000000
# max      468932.000000
# Name: price, dtype: float64

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
df.to_csv('laptop_data_cleaned.csv',index=False)

# %%
X=df.drop(columns=['price'])
y=df['price']

# %%
X.shape
# Out:
# (1224, 13)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=32)

# %%
X_train.shape,X_test.shape
# Out:
# ((1040, 13), (184, 13))

# %%
1040/1224
# Out:
# 0.8496732026143791

# %%
X_train
# Out:
#      Company            TypeName            Cpu  Ram             Gpu  \
# 460   Lenovo            Notebook  Intel Core i5    8        Intel HD
# 1161    Asus            Notebook  Intel Core i7   16  Nvidia GeForce
# 1192    Dell  2 in 1 Convertible  Intel Core i7   16  Nvidia GeForce
# 330     Dell            Notebook  Intel Core i5    8  Nvidia GeForce
# 1220  Lenovo  2 in 1 Convertible  Intel Core i7   16        Intel HD
# ...      ...                 ...            ...  ...             ...
# 1095      HP  2 in 1 Convertible  Intel Core i7    8        Intel HD
# 252   Lenovo            Notebook  Intel Core i3    4        Intel HD
# 88      Asus              Gaming  AMD FX Series    8      AMD Radeon
# 892      MSI              Gaming  Intel Core i7    8  Nvidia GeForce
# 727     Acer            Notebook  Intel Core i5    4        Intel HD
#
#            OpSys  Weight  IPS  Touchscreen  Cpu_speed   HDD  SSD  ppi
# 460   Windows 10    1.70    0            0        2.5     0  180  157
# 1161  Windows 10    2.20    0            0        2.8  1000  128  141
# 1192  Windows 10    2.77    0            1        2.7     0  512  127
# 330   Windows 10    2.00    0            0        1.6     0  256  141
# 1220  Windows 10    1.30    1            1        2.5     0  512  276
# ...          ...     ...  ...          ...        ...   ...  ...  ...
# 1095  Windows 10    1.48    0            1        2.6     0  256  221
# 252        No OS    2.20    0            0        2.0     0  256  141
# 88    Windows 10    2.45    0            0        3.0  1000    0  141
# 892   Windows 10    2.20    0            0        2.8  1000  128  141
# 727   Windows 10    2.10    0            0        2.5     0  256  100
#
# [1040 rows x 13 columns]

# %%
y_train
# Out:
# 460     130562
# 1161    167414
# 1192    172200
# 330     109384
# 1220    143484
#          ...
# 1095    172200
# 252      42500
# 88       66908
# 892     114768
# 727      57336
# Name: price, Length: 1040, dtype: int64

# %%
print(X_train.dtypes)
# Out:
# Company         object
# TypeName        object
# Cpu             object
# Ram              int64
# Gpu             object
# OpSys           object
# Weight         float64
# IPS              int64
# Touchscreen      int64
# Cpu_speed      float64
# HDD              int64
# SSD              int64
# ppi              int64
# dtype: object

# %%
# Company, TypeName, Cpu, Gpu, OpSys

# %%
# Encoding: Process of converting non-numerical data to numerical data
# Label Encoding
# Ordinal Encoding  : Ordered Data/ordinal data
# One Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor

# %%
# step 1 : onehot encoding within column transformer
# step 2: linear regression
# step1 + step2 = pipeline

# %%
X_train.sample()
# Out:
#   Company   TypeName            Cpu  Ram         Gpu   OpSys  Weight  IPS  \
# 3   Apple  Ultrabook  Intel Core i7   16  AMD Radeon  Mac OS    1.83    1
#
#    Touchscreen  Cpu_speed  HDD  SSD  ppi
# 3            0        2.7    0  512  221

# %%
# Linear Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8056790702988444
# RMSE     :    25872.876102061397
# MAE      :    19382.282004089277

# %%
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=40,stratify=df['Cpu'])

# %%
X_train[X_train['Cpu']=='AMD FX Series']
# Out:
#     Company TypeName            Cpu  Ram         Gpu       OpSys  Weight  IPS  \
# 900  Lenovo   Gaming  AMD FX Series   16  AMD Radeon  Windows 10    2.50    1
# 88     Asus   Gaming  AMD FX Series    8  AMD Radeon  Windows 10    2.45    0
#
#      Touchscreen  Cpu_speed   HDD  SSD  ppi
# 900            0        2.1  1000  512  141
# 88             0        3.0  1000    0  141

# %%
X_test[X_test['Cpu']=='AMD FX Series']
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Cpu, Ram, Gpu, OpSys, Weight, IPS, Touchscreen, Cpu_speed, HDD, SSD, ppi]
# Index: []

# %%
df[df['Cpu']=='AMD FX Series']
# Out:
#     Company TypeName            Cpu  Ram         Gpu       OpSys  Weight  \
# 88     Asus   Gaming  AMD FX Series    8  AMD Radeon  Windows 10    2.45
# 900  Lenovo   Gaming  AMD FX Series   16  AMD Radeon  Windows 10    2.50
#
#      price  IPS  Touchscreen  Cpu_speed   HDD  SSD  ppi
# 88   66908    0            0        3.0  1000    0  141
# 900  95624    1            0        2.1  1000  512  141

# %%
# y=m1x1+m2x2+m3x3+....+c
# Price= 0.5*cpu+10000*ram+0*ssd+0.4*ppi+0.03*company+..

# Some features which are irrelevant or noisy
# Features are highly correlated (multicollinearity)
# Too many features
# Overfitting

# %%
# Regularization
# L2 Regularization(Ridge Regression)
        # Penalize large coefficients
        # The model still uses all the features, but keeps their weights small
        # Generally works when there are many small/medium useful features
# L1 Regularization(Lasso Regression)
        # It can actually set some coefficients to zero, if the feature is not helping engough
# alpha

# %%
# Ridge Regression(L2 regularization)
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=Ridge()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8059480701827569
# RMSE     :    25854.96189443341
# MAE      :    19393.4336182393

# %%
# Lasso Regression(L1 regularization)
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=Lasso()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8057185203459725
# RMSE     :    25870.24967887573
# MAE      :    19377.977790173365

# %%
# KNN Regressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=KNeighborsRegressor(n_neighbors=4)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.687348220024937
# RMSE     :    32818.246428379316
# MAE      :    22068.375

# %%
# Support Vector Regressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=SVR(C=100000000)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.7366202991676197
# RMSE     :    30121.463504365594
# MAE      :    20694.25359495531

# %%
# DecisionTreeRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=DecisionTreeRegressor(max_depth=8)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.7618709403502862
# RMSE     :    28641.193901794613
# MAE      :    19877.747528841872

# %%
# AdaBoostRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=AdaBoostRegressor(n_estimators=5)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.6855225574547783
# RMSE     :    32913.92449124702
# MAE      :    26790.128967904384

# %%
# RandomForestRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=RandomForestRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8533923955282896
# RMSE     :    22473.10949358478
# MAE      :    16400.925881685645

# %%
# XGBRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=XGBRegressor(max_depth=3,n_estimators=100)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8747457265853882
# RMSE     :    20772.13671875
# MAE      :    15947.0634765625

# %%
# GradientBoostingRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=GradientBoostingRegressor(max_depth=5)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8737660008887044
# RMSE     :    20853.218292244354
# MAE      :    15753.426758177275

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))

# %%
# Streamlit

# %%
# !pip install streamlit --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 49.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 64.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.0 MB/s eta 0:00:00

# %%
# %%writefile abc.txt
# This is my text file
# I am adding another line of text here.
# And another as well
# Out:
# Writing abc.txt

# %%
# %%writefile app.py
import streamlit as st
import numpy as np
import pickle
lr_model=pickle.load(open('pipe.pkl','rb'))
df=pickle.load(open('df.pkl','rb'))

st.title("Laptop Price Predictor App")
st.write("This app is created using the data taken from kaggle website.")
st.write("The prediction here is based on the data available, hence might not align perfectly with the real-life data.")

company=st.selectbox("Laptop Manufacturer",df['Company'].unique(),index=4)
typename=st.selectbox("Type of Laptop",df['TypeName'].unique(),index=1)
cpu=st.selectbox("Processor",df['Cpu'].unique(),index=0)
cpu_speed=st.slider("CPU Clock Speed",min_value=0.8,max_value=4.0,step=0.1,value=2.5)
ram=st.radio("Amount of RAM on the system",[4,6,8,12,16,24,32,64,128],index=2,horizontal=True)
gpu=st.selectbox("Graphics Card on the system",df['Gpu'].unique(),index=1)
os=st.selectbox("Operating System",df['OpSys'].unique(),index=2)
weight=st.slider("Weight of the laptop(in kg)",min_value=0.6,max_value=5.0,step=0.2,value=2.0)
ips=st.selectbox("Does the laptop display have IPS Panel?",["Yes",'No'],index=1)
touchscreen=st.selectbox("Does the laptop have a touchscreen?",["Yes",'No'],index=1)
ssd=st.selectbox("What is the SSD storage on the system? If system has HDD storage only, select 0",
                 [0,128,256,512,1024],index=3)
hdd=st.selectbox("What is the HDD storage on the system? If system has SSD only, then select 0",
                 [0,128,256,512,1024,2048],index=0)
screen_size=st.slider("Screen size(in inches, measured diagonally)",min_value=10.0,max_value=18.5,step=0.1,value=15.6)
screen_resolution=st.selectbox("Screen Resolution(in horizontal x vertical pixels)",
                               ["2560x1600","1440x900","1920x1080","2880x1800","1366x768","2304x1440",
                                "3200x1800","1920x1200","2256x1504","3840x2160","2160x1440","2560x1440",
                                "1600x900","2736x1824","2400x1600"],index=2)
if st.button("PREDICT PRICE"):
    X_res=int(screen_resolution.split('x')[0])
    Y_res=int(screen_resolution.split('x')[1])
    ppi=(X_res**2+Y_res**2)**0.5/screen_size
    if ips=='Yes':
        ips=1
    else:
        ips=0
    if touchscreen=='Yes':
        touchscreen=1
    else:
        touchscreen=0
    query=np.array([[company,typename,cpu,ram,gpu,os,weight,ips,touchscreen,cpu_speed,hdd,ssd,ppi]])
    op=lr_model.predict(query)
    st.subheader("The predicted price of the laptop with the above mentioned specification is ₹"+ str(int(round(op[0],-2))))
# Out:
# Writing app.py

# %%
X_train.sample()
# Out:
#     Company  TypeName            Cpu  Ram        Gpu       OpSys  Weight  IPS  \
# 478  Lenovo  Notebook  Intel Core i7    8  Intel UHD  Windows 10    2.17    0
#
#      Touchscreen  Cpu_speed  HDD  SSD  ppi
# 478            0        1.8    0  256  141

# %%
print(df['Weight'].describe())
# Out:
# count    1224.000000
# mean        2.063204
# std         0.663863
# min         0.690000
# 25%         1.597500
# 50%         2.060000
# 75%         2.320000
# max         4.700000
# Name: Weight, dtype: float64

# %%
df['OpSys'].unique()
# Out:
# array(['Mac OS', 'No OS', 'Windows 10', 'Linux/Others', 'Windows 7'],
#       dtype=object)

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠙⠹⠸
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.237.55.160:8501
#
# ⠼⠴⠦⠧⠇Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇your url is: https://lovely-rooms-heal.loca.lt
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
